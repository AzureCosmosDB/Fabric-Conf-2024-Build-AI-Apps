# %%
# Download the file from the blob storage
stream = blob_client.download_blob().readall()

# Use ijson to parse the json file incrementally
objects = ijson.items(stream, 'item')

for obj in objects:
    # serialize the object to a string
    sObject = json.dumps(obj)
    
    # generate an embedding for each object
    vectorArray = generate_embeddings(sObject)

    # add the embedding to the object
    obj[mongo_vector_property] = vectorArray

    # insert the object into the collection
    collection.insert_one(obj)



stream = urllib.request.urlopen('https://cosmosdbcosmicworks.blob.core.windows.net/fabcondata/arxiv-metadata-oai-snapshot.json')

for object in ijson.items(stream, 'item'):
        
    # serialize the object to a string
    sObject = json.dumps(object)

    # generate an embedding for each object
    vectorArray = generate_embeddings(sObject)

    # add the embedding to the object
    object[mongo_vector_property] = vectorArray

    # insert the object into the collection
    collection.insert_one(object)
        
print("Data inserted into collection: '{}'.\n".format(collection.name))




with blob_client.download_blob().readinto(stream):

    for line in stream:
        # read the line as a string
        line = line.decode('utf-8')
        
        # parse the line as JSON
        object = json.loads(line)
        
        # serialize the object to a string
        sObject = json.dumps(object)
        
        # generate an embedding for each object
        vectorArray = generate_embeddings(sObject)
        
        # add the embedding to the object
        object[mongo_vector_property] = vectorArray
        
        # insert the object into the collection
        collection.insert_one(object)

        
print("Data inserted into collection: '{}'.\n".format(collection.name))




#stream = urllib.request.urlopen('https://cosmosdbcosmicworks.blob.core.windows.net/fabcondata/arxiv-metadata-oai-snapshot.json')
stream = urllib.request.urlopen('https://cosmosdbcosmicworks.blob.core.windows.net/fabcondata/movielens_dataset.json')

success = True

counter = 0

for line in stream:

    try:
        
        # serialize the object to a string
        sObject = json.loads(line.decode('utf-8'))

        
        # generate an embedding for each object
        vectorArray = generate_embeddings(sObject)

        # add the embedding to the object
        sObject[mongo_vector_property] = vectorArray

        # insert the object into the collection
        collection.insert_one(sObject)

        counter += 1

        if counter % 1000 == 0:
            print("Inserted {} documents into collection: '{}'.".format(counter, collection.name))

    except Exception as e:
        print(e)
        success = False
        break

if success:
    print("Data inserted into collection: '{}'.\n".format(collection.name))
